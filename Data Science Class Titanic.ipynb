# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("train.csv")

# %%
data.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
output = sns.countplot(x="Survived", data=data)

# %% [markdown]
# ## Over 500 people died while less than 400 survived

# %%
Pclass = sns.countplot(x="Pclass", data=data)

# %% [markdown]
# ## There are three classes on the boat S, C and Q
# The third class has the highest amount of passengers

# %%
data.hist(column = "Pclass")
# Out:
# array([[<AxesSubplot:title={'center':'Pclass'}>]], dtype=object)

# %%
sns.distplot(data["Pclass"])
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %% [markdown]
# ## This shows a discrete districbution with only three possible outcomes

# %%
age = sns.distplot(data["Age"])

# %%
sns.countplot(x="Age", data=data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
data.hist("Age")
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %% [markdown]
# ## Age analysis
# 1. From the visualization the average age seems to be 30 with about 180 people
# 2. There areabout 50 children on board
# 3. The boat has a majority youth population

# %%
sns.countplot(x="SibSp", data=data)   #try checking is SibSp affected survival
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %% [markdown]
# ## 600 people came alone, 200 came with either 1 spouse or sibling, others had more...(maybe a family vacation lol)

# %%
sns.countplot(x="Parch", data=data)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %% [markdown]
# ## Almost 700 people came alone
# ## I have a feeling being alone affects survival.... who knows????

# %%
sns.countplot(x="Fare", data=data) #fare and Pclass might have a relationship or emvarked!
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='count'>

# %%
data.hist("Fare")
# Out:
# array([[<AxesSubplot:title={'center':'Fare'}>]], dtype=object)

# %%
sns.distplot(data["Fare"])
# Out:
# <AxesSubplot:xlabel='Fare'>

# %% [markdown]
# ## The only sense i can make out from this is that most people paid less than 100$ for the cruise

# %%
sns.swarmplot(x="Survived", y="Age" ,hue="Sex", data=data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.countplot(x="Pclass",hue= "Survived", data=data)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x="SibSp",hue= "Survived", data=data)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
sns.countplot(x="Age",hue= "Survived", data=data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.swarmplot(x="Survived", y="Age", data=data) #, order=["Dinner", "Lunch"])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
alive = data[data["Survived"]==1]
alive.sum()
# Out:
# PassengerId                                               151974
# Survived                                                     342
# Pclass                                                       667
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex            femalefemalefemalefemalefemalefemalefemalefema...
# Age                                                      8219.67
# SibSp                                                        162
# Parch                                                        159
# Ticket         PC 17599STON/O2. 3101282113803347742237736PP 9...
# Fare                                                     16551.2
# dtype: object

# %%
dead = data[data["Survived"]==0]
dead.sum()
# Out:
# PassengerId                                               245412
# Survived                                                       0
# Pclass                                                      1390
# Name           Braund, Mr. Owen HarrisAllen, Mr. William Henr...
# Sex            malemalemalemalemalemalemalefemalemalefemalema...
# Age                                                      12985.5
# SibSp                                                        304
# Parch                                                        181
# Ticket         A/5 2117137345033087717463349909A/5. 215134708...
# Fare                                                     12142.7
# Embarked       SSQSSSSSQSSSCSSCSCSSSSSCSQCSSSCCSCSSCSSSSSCSSS...
# dtype: object

# %%
sns.distplot(dead["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.distplot(alive["SibSp"])
# Out:
# <AxesSubplot:xlabel='SibSp'>

# %%
survived = data["Survived"]
 if survived == 0
# Out:
#   File "<ipython-input-26-ac99c1fdd08e>", line 2
#     if survived == 0
#     ^
# IndentationError: unexpected indent
